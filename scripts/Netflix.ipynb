# %%
import pandas as pd

# %%
df = pd.read_csv('NetflixOriginals.csv')
df
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# ...

# %%
score = df.sort_values('IMDB Score', ascending=False)[:15]
score
# Out:
#                                            Title  \
# 583     David Attenborough: A Life on Our Planet
# 582    Emicida: AmarElo - It's All For Yesterday
# 581                      Springsteen on Broadway
# 580  Winter on Fire: Ukraine's Fight for Freedom
# 579        Taylor Swift: Reputation Stadium Tour
# 578   Ben Platt: Live from Radio City Music Hall
# 577                       Dancing with the Birds
# 576                      Cuba and the Cameraman
# 573                                        Klaus
# 571                                         13th
# 572            Disclosure: Trans Lives on Screen
# 575        The Three Deaths of Marisela Escobedo
# 574                                   Seaspiracy
# 570                               Rising Phoenix
# 569                           My Octopus Teacher
#
#                                     Genre           Premiere  Runtime  \
# 583                           Documentary    October 4, 2020       83
# ...

# %%
length = score[['Title','Runtime']]
length
# Out:
#                                            Title  Runtime
# 583     David Attenborough: A Life on Our Planet       83
# 582    Emicida: AmarElo - It's All For Yesterday       89
# 581                      Springsteen on Broadway      153
# 580  Winter on Fire: Ukraine's Fight for Freedom       91
# 579        Taylor Swift: Reputation Stadium Tour      125
# 578   Ben Platt: Live from Radio City Music Hall       85
# 577                       Dancing with the Birds       51
# 576                      Cuba and the Cameraman       114
# 573                                        Klaus       97
# 571                                         13th      100
# 572            Disclosure: Trans Lives on Screen      107
# 575        The Three Deaths of Marisela Escobedo      109
# 574                                   Seaspiracy       89
# 570                               Rising Phoenix      106
# 569                           My Octopus Teacher       85

# %%
runtime = length.plot.bar(x='Title', y='Runtime',figsize=(20,10))
runtime.set_ylabel("minutes")
runtime.set_xlabel("title")
# Out:
# Text(0.5, 0, 'title')

# %%
sort_runtime = length.sort_values('Runtime', ascending=False)
sort_runtime
# Out:
#                                            Title  Runtime
# 581                      Springsteen on Broadway      153
# 579        Taylor Swift: Reputation Stadium Tour      125
# 576                      Cuba and the Cameraman       114
# 575        The Three Deaths of Marisela Escobedo      109
# 572            Disclosure: Trans Lives on Screen      107
# 570                               Rising Phoenix      106
# 571                                         13th      100
# 573                                        Klaus       97
# 580  Winter on Fire: Ukraine's Fight for Freedom       91
# 582    Emicida: AmarElo - It's All For Yesterday       89
# 574                                   Seaspiracy       89
# 578   Ben Platt: Live from Radio City Music Hall       85
# 569                           My Octopus Teacher       85
# 583     David Attenborough: A Life on Our Planet       83
# 577                       Dancing with the Birds       51

# %%
sorted_runtime = sort_runtime.plot.bar(x='Title', y='Runtime',figsize=(20,10))
sorted_runtime.set_ylabel("minutes")
sorted_runtime.set_xlabel("title")
# Out:
# Text(0.5, 0, 'title')

# %%
sort_runtime = sort_runtime.set_index('Title')

# %%
longest = sort_runtime.loc['Springsteen on Broadway']
longest
# Out:
# Runtime    153
# Name: Springsteen on Broadway, dtype: int64

# %%
shortest = sort_runtime.loc['Dancing with the Birds']
shortest
# Out:
# Runtime    51
# Name: Dancing with the Birds, dtype: int64

# %%
difference = longest - shortest
difference
# Out:
# Runtime    102
# dtype: int64

# %%
difference[0]
# Out:
# 102

# %%
value = difference[0]

# %%
print(f'The difference in runtime length between the longest and shortest movie is {value} minutes.')
# Out:
# The difference in runtime length between the longest and shortest movie is 102 minutes.
